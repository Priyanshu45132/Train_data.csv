# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanshu45132/Train_data.csv/blob/main/Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('/content/train.csv')

# %%
df1.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print("No. of rows",df1.shape[0])
print("NO of column",df1.shape[1])
# Out:
# No. of rows 891
# NO of column 12

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
# Data Filtering

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
sum(df1['Sex']=='female')
# Out:
# 314

# %%
df1[df1['Sex']=='female'].head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
sum(df1['Survived']==1)
# Out:
# 342

# %%
df1[df1['Survived']==1].head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %%
df1['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df1['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df1['Embarked']=df1['Embarked'].fillna('S')

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %%
x=df1['Age'].mean()

# %%
df1['Age']=df1['Age'].fillna(x)

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %%
df1['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
#Drop

# %%
df1=df1.drop('Cabin',axis=1)

# %%
df1.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Embarked
# 0      0  A/5 21171   7.2500        S
# 1      0   PC 17599  71.2833        C

# %%
#catagorial data encoding

# %%
df1['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df1['Gender']=df1['Sex'].map({'male':1 , 'female':0})

# %%
df1.insert(5,'Gender',df1.pop('Gender'))

# %%
df1.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Gender   Age  \
# 0                            Braund, Mr. Owen Harris    male       1  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       0  38.0
# 2                             Heikkinen, Miss. Laina  female       0  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       0  35.0
# 4                           Allen, Mr. William Henry    male       1  35.0
#
#    SibSp  Parch            Ticket     Fare Embarked
# 0      1      0         A/5 21171   7.2500        S
# 1      1      0          PC 17599  71.2833        C
# 2      0      0  STON/O2. 3101282   7.9250        S
# 3      1      0            113803  53.1000        S
# ...

# %%
df1['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
pd.get_dummies(df1,columns=['Embarked'],dtype=int,drop_first=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Gender  \
# 0                              Braund, Mr. Owen Harris    male       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       0
# 2                               Heikkinen, Miss. Laina  female       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       0
# 4                             Allen, Mr. William Henry    male       1
# ..                                                 ...     ...     ...
# ...

# %%
## UNIVARIET Analysis

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df1['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='Survived',data=df1)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df1['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df1['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass',data=df1)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df1['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex',data=df1)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.hist(df1['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df1['Age'],orient='v')
# Out:
# <Axes: ylabel='Age'>

# %%
# Bivarient Analysis

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
sns.barplot(x='Sex',y='Survived',data=df1)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
sns.barplot(x='Pclass',y='Survived',data=df1)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
# Feature Engineering

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df1['Family_Size']=df1['SibSp']+df1['Parch']

# %%
df1.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Gender   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris  male       1  22.0
#
#    SibSp  Parch     Ticket  Fare Embarked  Family_Size
# 0      1      0  A/5 21171  7.25        S            1

# %%
df1['Cost']=df1['Fare']/(df1['Family_Size']+1)

# %%
df1.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Gender   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris  male       1  22.0
#
#    SibSp  Parch     Ticket  Fare Embarked  Family_Size   Cost
# 0      1      0  A/5 21171  7.25        S            1  3.625
